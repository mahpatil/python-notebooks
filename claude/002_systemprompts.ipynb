# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv
import os
load_dotenv()
from anthropic import Anthropic, HUMAN_PROMPT, AI_PROMPT
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages, system_prompt=None, temperature=0.7):
    params = {
        "model": model,
        "messages": messages,
        "max_tokens": 300,
        "temperature": temperature
    }
    if system_prompt is not None:
        params["system"] = system_prompt

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# import pprint
# system_prompt = "You are a helpful patient Mathematics tutor. Do not directly answer a student's question. Guide them to the answer step by step."
# messages = []
# while True:
#     prompt =input("What would you look to do> ")
#     add_user_message(messages, prompt)
#     answer = chat(messages, system_prompt)
#     pprint.pp(answer)

#     add_assistant_message(messages, answer)

# %%
## python prompt exercise
import pprint
system_prompt = "You are a Python programmer who writes concise code."
messages = []
add_user_message(messages, "Write a python function that checks a string for duplicate characters.")
answer = chat(messages, system_prompt)
print(answer.encode('utf-8').decode('unicode_escape'))
# Out:
# Here's a concise Python function that checks a string for duplicate characters:
#
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```
#
# This function returns `True` if the string contains duplicate characters, and `False` otherwise.
#
# **Example usage:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False (all unique)
# print(has_duplicates("python"))  # False (all unique)
# print(has_duplicates("abcabc"))  # True  (a, b, c appear twice)
# ```
#
# If you'd also like to **identify which characters are duplicates**, here's an extended version:
#
# ```python
# def find_duplicates(s):
#     seen = set()
#     duplicates = set()
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#     return duplicates
# ```
#
# **Example usage:**
# ```python
# print(find_duplicates("hello"))   # {'l'}
# ...

# %%
messages = []
add_user_message(messages,"Generate a one line movie idea")
answer = chat(messages, temperature=0.0)
print(answer)
answer = chat(messages, temperature=1.0)
print(answer)
answer = chat(messages, temperature=0.3)
print(answer)
# Out:
# **"A retired safecracker with dementia must break into a bank vault — the only place he hid the memories of his missing daughter."**
# **A retired assassin discovers the person who hired him for his final job was his estranged daughter, trying to save him from a rival who put a bounty on his head.**
# **A retired safecracker with dementia must break into a bank vault — the only place he hid the evidence to save his wrongly convicted son.**

# %%
messages = []
add_user_message(messages,"Generate a one line movie idea")
answer = chat(messages, temperature=0.0)
print(answer)
answer = chat(messages, temperature=0.3)
print(answer)
answer = chat(messages, temperature=1.0)
print(answer)
# Out:
# **A retired safecracker with dementia must break into a bank vault — the only place he hid the memories of his missing daughter.**
# **A retired safecracker with dementia must break into a vault before he forgets the combination he memorized in his mind.**
# **A blind musician begins hearing the last thoughts of murder victims through their favorite songs, leading him to the killer — who turns out to be his piano teacher.**

# %%
messages = []
add_user_message(messages,"Generate a one line movie idea")
answer = chat(messages, temperature=0.0)
print(answer)
answer = chat(messages, temperature=0.3)
print(answer)
answer = chat(messages, temperature=1.0)
print(answer)
# Out:
# **A retired safecracker with dementia must break into a bank vault — the only place he hid the evidence that could save his wrongly convicted son.**
# **A retiring assassin discovers the next target on his list is his own estranged daughter.**
# **A retired safecracker with dementia must break into a bank vault — the only place he hid the memories of his missing daughter.**

# %%
answer = chat(messages, temperature=1.0)
print(answer)
# Out:
# **A washed-up magician discovers his tricks are suddenly real, but every wish granted slowly erases a memory from his past.**
