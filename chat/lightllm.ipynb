# %%
import torch
from transformers import pipeline


#summarizer = pipeline("summarization", model="t5-small", device=-1)  # device=-1 for CPU
summarizer = pipeline("summarization", model="Qwen/Qwen2-0.5B", device=-1)  # device=-1 for CPU
text = "In the third quarter of 2025, the company experienced significant growth in its consumer electronics division, "
"driven by strong demand for wearable devices and smart home products. Despite supply chain challenges, overall revenue increased, "
"and customer satisfaction scores improved."
"Wearable Devices: 12,400: 3,100,000: 92"
"Smart Home Products: 8,300: 2,500,000: 89"
"Mobile Accessories: 5,200: 780,000: 85"
"Audio Equipment: 4,600: 1,200,000: 88"
" The marketing campaign launched in July contributed to a notable rise in new customer acquisitions."
summary = summarizer(text)

print("**Summary below**")
print(summary)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       2 from transformers import pipeline
#       5 #summarizer = pipeline("summarization", model="t5-small", device=-1)  # device=-1 for CPU
# ----> 6 summarizer = pipeline("summarization in less than 100 words", model="Qwen/Qwen2-0.5B", device=-1)  # device=-1 for CPU
#       7 text = "In the third quarter of 2025, the company experienced significant growth in its consumer electronics division, "
#       8 "driven by strong demand for wearable devices and smart home products. Despite supply chain challenges, overall revenue increased, "
#
# ...
